# %%
# !python3 /home/sungwoopark/dl-practice/vision/main.py --dataset cifar100 --bs 512 --use_wandb --wandb cnn --name googleresnet --img_size 224 --drop_fc 0.5 --save_plot --num_workers 4 --lr 75e-5 --label_smoothing 0.002 --tqdm --google_modified 1 --epoch 100 --tqdm --optim adamax
# Out:
# Using PyTorch version: 1.13.0, Device: cuda
# wandb: Currently logged in as: swpark9514. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.13.9
# wandb: Run data is saved locally in /home/sungwoopark/dl-practice/vision/wandb/run-20230128_010438-qajpa6hh
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run incandescent-kumquat-59
# wandb: ⭐️ View project at https://wandb.ai/swpark9514/cnn
# wandb: 🚀 View run at https://wandb.ai/swpark9514/cnn/runs/qajpa6hh
# Files already downloaded and verified
# Files already downloaded and verified
# ...
# Layer (type:depth-idx)                   Param #
# ...
# DataParallel                             --
# ├─GoogLeResNet: 1-1                      --
# │    └─Sequential: 2-1                   --
# │    │    └─Conv2d: 3-1                  18,944
# │    │    └─BatchNorm2d: 3-2             256
# │    │    └─ReLU: 3-3                    --
# │    └─Sequential: 2-2                   --
# ...
